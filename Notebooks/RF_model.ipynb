# %% [markdown]
# # Density RF Model
#
# Barebones notebook to reproduce the Murphy et al. [2024] density model.
#
# Only the model is reproduced, no testing is done (residuals, hyperparameters, permutation importance, etc.). This was done in another set of analysis and removing it here simplifies the notebook.

# %%
import pandas as pd
import numpy as np
import time
import gc
import pickle
import os

from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.metrics import median_absolute_error
from sklearn.metrics import r2_score

# %%
# random state and random forest parameters
# random state ensures the same model is generated

rnd=17
rf_params = {
    "n_estimators": 500,
    "max_depth": None,
    "min_samples_split": 2,
    "min_samples_leaf":5,
    "warm_start":False,
    "oob_score":True,
    "random_state": rnd,
    "max_features":0.5,
    "n_jobs":10
    }

# %%
def dat_create(dat, col, log_col, lt_col, y_col, t_col):

    x_dat = dat[col+t_col+[y_col]].dropna().copy()

    if log_col:
       for i in log_col:
            try:
                x_dat[i] = np.log10(x_dat[i])
            except:
                print(f'Could not log column {i}')
    
    if lt_col:
        for i in lt_col:
            try:
                if dat[i].max() > 24:
                    x_dat[f'cos_{i}'] = np.cos(dat[i]*2*np.pi/360.)
                    x_dat[f'sin_{i}'] = np.sin(dat[i]*2*np.pi/360.)
                else:
                    x_dat[f'cos_{i}'] = np.cos(dat[i]*2*np.pi/24.)
                    x_dat[f'sin_{i}'] = np.sin(dat[i]*2*np.pi/24.)    
            except:
                print(f'Could not add {i} as a cos/sin time column')
    
    x_dat = x_dat[~x_dat.isin([np.nan, np.inf, -np.inf]).any(axis=1)].dropna()
    y_dat = x_dat[y_col].copy()
    x_dat = x_dat.drop(columns=y_col)    
    
    return x_dat, y_dat

# %%
def rf_model(col=['1300_02', 'SYM_H index','SatLat'], 
             y_col='400kmDensity', 
             t_col=['DateTime'], 
             log_col=['1300_02'], 
             lt_col=['SatMagLT'], 
             rf_params=rf_params, 
             target_dat='D:\\data\\SatDensities\\satdrag_database_grace_B.hdf5', 
             oos_dat='D:\\data\\SatDensities\\satdrag_database_grace_A.hdf5',
             oos_dat2='D:\\data\\SatDensities\\satdrag_database_grace_CHAMP_SI_int.hdf5',
             n_repeats=10):
    
    
    rnd = rf_params['random_state']
    
    dat_dic = {'feature_cols':col,
               'target_cols':y_col,
               'time_cols':t_col,
               'log_col':log_col,
               'lt_col':lt_col}

    kcol = [col,[y_col],t_col,lt_col]
    kflt = [item for sublist in kcol for item in sublist]
    df = pd.read_hdf(target_dat)
    df = df[kflt].dropna()

    reg_x, reg_y = dat_create(dat=df,col=col,log_col=log_col,lt_col=lt_col,
                              y_col=y_col,t_col=t_col)
    reg_y = reg_y*(10**12)
    

    # create data set from out of sample data
    df_oos = pd.read_hdf(oos_dat)
    oos_x, oos_y = dat_create(dat=df_oos,col=col,log_col=log_col,lt_col=lt_col,
                              y_col=y_col,t_col=t_col)
    oos_y = oos_y*(10**12)
    oos_t = oos_x[t_col]
    oos_x = oos_x.drop(columns=t_col)
    

    df_oos2 = pd.read_hdf(oos_dat2)
    oos_x2, oos_y2 = dat_create(dat=df_oos2,col=col,log_col=log_col,lt_col=lt_col,
                                y_col=y_col,t_col=t_col)
    oos_y2 = oos_y2*(10**12)
    oos_t2 = oos_x2[t_col]
    oos_x2 = oos_x2.drop(columns=t_col)

    del df
    del df_oos
    del df_oos2
    gc.collect
    
    # create train test splits
    train_x, test_x, train_y, test_y = train_test_split(reg_x, reg_y, 
                                                        test_size=0.3, 
                                                        random_state=rnd)

    # get and drop DateTime column
    train_t = train_x[t_col].copy()
    test_t = test_x[t_col].copy()

    train_x = train_x.drop(columns=t_col)
    test_x = test_x.drop(columns=t_col)

    print('Train and fit model')

    start = time.time()
    print("Time elapsed working on RandomForest")

    rfr = RandomForestRegressor(**rf_params)
    rfr.fit(train_x, train_y)

    end = time.time()
    print("Time consumed in working: ",end - start)

    #Make predictions and calculate error
    predictions = rfr.predict(test_x)
    pre_oos = rfr.predict(oos_x)
    pre_oos2 = rfr.predict(oos_x2)
    pre_tr = rfr.predict(train_x)
    
    # combine data sets into single dataframes
    train_d = train_x.join([train_y,train_t], how='left')
    test_d = test_x.join([test_y,test_t], how='left')
    oos_d = oos_x.join([oos_y,oos_t], how='left')
    oos2_d = oos_x2.join([oos_y2,oos_t2], how='left')
    
    # add predictions to the dataframes
    train_d[y_col+'_pred'] = pre_tr
    test_d[y_col+'_pred'] = predictions
    oos_d[y_col+'_pred'] = pre_oos
    oos2_d[y_col+'_pred'] = pre_oos2
    
    
    
    return rfr, train_d, test_d, oos_d, oos2_d, dat_dic

# %%
def rf_run(y_col='400kmDensity', 
           lt_col=['SatMagLT'],
           pre_f = False,
           app_f = False
           ):
    """
    Run a set of random forest models 

    Returns
    -------
    None.
    
    Saves data frames to file for subsequent analysis

    """
    
    # out_dir 
    o_dir = 'D:\\data\\SatDensities\\'
    
    # repeats for permutation importance
    n_repeats = 5
    # columns that are not used in the model but are returned
    # to make subsequent analysis easier
    t_col = ['DateTime','storm','storm phase']
    
    # columns to log for fism and geo datasets
    fi_log = ['1300_02', '43000_09', '85550_13', '94400_18']
    
    # solar indice columns
    si_col = ['F10', 'F81', 'S10', 'S81c', 'M10', 'M81c', 'Y10', 'Y81c', 'SatLat']
            
    # fism2 columns
    fi_col = ['1300_02', '43000_09', '85550_13', '94400_18', 'SatLat']
 
    # fism2 and geo columns
    fgeo_col = ['1300_02', '43000_09', '85550_13', '94400_18', 'SYM_H index', 'AE', 'SatLat']

    # labels
    data_labels = ['SI','FI','FI_GEO']
    data_sets = [si_col, fi_col, fgeo_col]

    data_labels = ['FI_GEO']
    data_sets = [fgeo_col]
    
    for col, d_in in zip(data_sets,data_labels):
        
        print(d_in)

        rf_dat = rf_model(y_col=y_col, lt_col=lt_col,
                          col=col, t_col=t_col, log_col=fi_log, 
                          n_repeats=n_repeats)
        
        fn = f'{d_in}_RFdat'
        if pre_f:
            fn = f'{pre_f}{fn}'
        if app_f:
            fn = f'{fn}{app_f}'
            
        fn = f'{fn}.pkl'
        fn = os.path.join(o_dir,fn)
        
        with open(fn, 'wb') as f:
            pickle.dump(rf_dat, f)
            
        del rf_dat
        gc.collect

# %%
rf_run(app_f='_AIMFAHR')
# Out:
# FI_GEO
# c:\Users\krmurph1\Anaconda3\envs\satdrag\lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# c:\Users\krmurph1\Anaconda3\envs\satdrag\lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# c:\Users\krmurph1\Anaconda3\envs\satdrag\lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Train and fit model
# Time elapsed working on RandomForest
# Time consumed in working:  598.991756439209

# %%
new = pd.read_pickle("D:\data\SatDensities\FI_GEO_RFdat_AIMFAHR.pkl")

# %%
new[-1]
# Out:
# {'feature_cols': ['1300_02',
#   '43000_09',
#   '85550_13',
#   '94400_18',
#   'SYM_H index',
#   'AE',
#   'SatLat'],
#  'target_cols': '400kmDensity',
#  'time_cols': ['DateTime', 'storm', 'storm phase'],
#  'log_col': ['1300_02', '43000_09', '85550_13', '94400_18'],
#  'lt_col': ['SatMagLT']}

# %%
new[-2].head()
# Out:
#          1300_02   43000_09  85550_13  94400_18  SYM_H index    AE    SatLat  \
# 105120  7.648391  10.081208  9.545769  9.306003         -5.0  23.0  43.79120
# 105121  7.650381  10.061229  9.536066  9.306486         -4.0  20.0  24.33522
# 105122  7.650341  10.061380  9.536143  9.306490         -4.0  26.0   6.12783
# 105123  7.650220  10.061382  9.535996  9.306390         -3.0  23.0 -15.32528
# 105124  7.650038  10.061252  9.535645  9.306199         -3.0  27.0 -33.78976
#
#         cos_SatMagLT  sin_SatMagLT  400kmDensity            DateTime  storm  \
# 105120     -0.580710     -0.814110      3.659148 2003-01-01 00:00:00      1
# 105121     -0.504256     -0.863554      4.745748 2003-01-01 00:05:00      1
# 105122     -0.444752     -0.895654      5.470819 2003-01-01 00:10:00      1
# 105123     -0.369925     -0.929062      5.239831 2003-01-01 00:15:00      1
# 105124     -0.274488     -0.961591      5.050540 2003-01-01 00:20:00      1
#
#         storm phase  400kmDensity_pred
# 105120            2           4.082639
# 105121            2           4.586757
# 105122            2           4.619495
# 105123            2           3.989298
# 105124            2           3.744127

# %%
dat = pd.read_hdf('D:\\data\\SatDensities\\satdrag_database_grace_CHAMP_SI_int.hdf5')

# %%
dat.loc[105120,'43000_09']
# Out:
# 9.545769348360656

# %%
new[1].head()
# Out:
#          1300_02  43000_09  85550_13  94400_18  SYM_H index     AE    SatLat  \
# 200511  7.490862  9.911153  9.455465  9.228625        -15.0  105.0 -60.03617
# 242348  7.465065  9.924064  9.463639  9.232483         -6.0   18.0 -60.03854
# 994822  7.696125  9.986703  9.501317  9.272544          5.0   22.0 -87.11732
# 779234  6.966885  9.780912  9.396972  9.171520        -10.0   78.0  25.74049
# 623312  6.596638  9.738198  9.379986  9.153376          3.0   19.0 -20.07795
#
#         cos_SatMagLT  sin_SatMagLT  400kmDensity            DateTime  storm  \
# 200511     -0.494025      0.869448      0.987248 2004-06-27 05:15:00     -1
# 242348     -0.870029      0.493001      3.009913 2004-11-19 11:40:00     -1
# 994822      0.919029      0.394191      2.751377 2012-01-15 05:50:00     -1
# 779234      0.544046      0.839055      0.329241 2009-12-27 16:10:00     -1
# 623312      0.625324     -0.780365      0.132017 2008-07-04 06:40:00     -1
#
#         storm phase  400kmDensity_pred
# 200511           -1           0.958129
# 242348           -1           2.395532
# 994822           -1           2.378069
# 779234           -1           0.294765
# 623312           -1           0.140145

# %%
rfr = est[0]

# %%
rfr.__getstate__()
# Out:
# {'estimator': DecisionTreeRegressor(),
#  'n_estimators': 500,
#  'estimator_params': ('criterion',
#   'max_depth',
#   'min_samples_split',
#   'min_samples_leaf',
#   'min_weight_fraction_leaf',
#   'max_features',
#   'max_leaf_nodes',
#   'min_impurity_decrease',
#   'random_state',
#   'ccp_alpha'),
#  'base_estimator': 'deprecated',
#  'bootstrap': True,
#  'oob_score': True,
#  'n_jobs': 10,
#  'random_state': 17,
#  'verbose': 0,
#  'warm_start': False,
#  'class_weight': None,
#  'max_samples': None,
#  'criterion': 'squared_error',
#  'max_depth': None,
#  'min_samples_split': 2,
#  'min_samples_leaf': 5,
#  'min_weight_fraction_leaf': 0.0,
#  'max_features': 0.5,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'ccp_alpha': 0.0,
#  'feature_names_in_': array(['1300_02', '43000_09', '85550_13', '94400_18', 'SYM_H index', 'AE',
#         'SatLat', 'cos_SatMagLT', 'sin_SatMagLT'], dtype=object),
#  'n_features_in_': 9,
#  'n_outputs_': 1,
#  'estimator_': DecisionTreeRegressor(),
#  'estimators_': [DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1265576559),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=780729585),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=131369103),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1478473094),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=822575510),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1670161721),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=291629808),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1317787565),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1232593174),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1761895455),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=671447364),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=442355239),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=590647764),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=942749612),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=324711943),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=557304705),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=167773934),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1545862161),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1536797737),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=177264312),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1914194698),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1041813986),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=257889923),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=302440255),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1563548934),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=147374043),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1620450470),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=925622235),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=219875113),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=2094092985),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=654632990),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1171262737),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=222270446),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=511373549),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=418816229),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1286918577),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=2076739616),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1622870845),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1215424901),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=4827110),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1278722214),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=2051412994),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=264178732),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=105962422),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1701010809),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=199532173),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1239960120),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1396248859),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1797376746),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1737744211),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=618062642),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1274559537),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=648139324),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=709243257),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=237259784),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=75678131),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=936462619),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1109816306),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1255493499),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=758130647),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=853727295),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=53654507),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1423197210),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1261374555),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=292019640),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=487976889),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=353646543),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=272253550),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=193267402),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1529958914),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=682722609),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=178464728),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=759188657),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1309582920),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=508834496),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=958137804),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1911243540),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1991032693),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1666371855),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1359309274),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1276755172),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1407409188),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=291966429),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1975140891),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1979068323),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1130385075),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=683781971),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=214998157),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=939636103),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1422160488),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1046154261),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=42468876),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1665314961),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=915251993),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=575292267),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=762211540),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1189596761),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1815198583),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1451662467),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1503843402),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1414353213),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=993707875),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=125228347),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1409576737),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1676645679),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1238234765),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1877982982),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1942477357),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=88626941),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1467275374),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=2116872001),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=85050798),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=560189483),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1815532835),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=2080411454),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=45937422),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=282189336),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1598458051),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=340522506),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1208536978),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=346925240),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=11759794),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1951366273),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=255206271),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=848014560),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=969043332),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=357879848),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1964100290),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1648684273),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=707176756),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=67414634),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1529546468),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1269569327),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=2047631043),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1151869174),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1938703938),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1597915896),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=717916090),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1787179214),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1688307991),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1176018709),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=643603879),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1015249213),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=967026339),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1333672563),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1773817945),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=926180750),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1162017688),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=355346231),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1686033301),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=753708522),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=750999224),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1539851718),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=2098924788),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=828485818),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=104783170),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1224425122),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1422914417),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1517331416),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1971350082),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=945717734),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=990718287),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1053866388),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1122861337),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=976729341),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=683492073),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=275426667),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=2064309253),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1948787561),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1075328706),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=2094558189),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=680219805),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=605052795),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=173635232),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=455991762),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=638123769),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=316152268),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=471916298),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1977170140),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=293188289),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=67347576),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1493942529),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=299896288),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=75170837),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=2095972661),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1567584710),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1429669782),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=524867029),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=2139510839),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=985921083),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=344247386),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1994026514),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1593634694),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=105779656),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=915199146),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=781559014),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=996913660),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=535392043),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1389937248),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1688849657),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1052177711),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=587344783),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1774090473),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1996021623),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=63158930),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=9735004),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1488384391),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=568368410),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1541300768),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1870017210),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1333602855),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=426250945),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=512760664),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=231560193),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=90020283),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1993888014),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1928225859),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=654003257),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1706335847),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1737996269),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=2117858431),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=242967783),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=19230803),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1253745993),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1568194114),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=688263806),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1215502042),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=356825980),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1923814702),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1963117973),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=558410225),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=689984885),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=691973634),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=2116022871),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=703224917),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1914462075),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1326881896),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=214297106),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=2004161263),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=527229810),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=2073845048),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1665482504),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=175008946),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=67785497),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=906981725),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1733337110),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=805013197),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1475991683),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=158781260),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=2114310003),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1667179880),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1885788235),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=809962990),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1885002188),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1211299992),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1784378191),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=618157999),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=390632848),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=2084772796),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=378387573),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1842734004),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1035511419),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1159131865),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=177704708),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1349388463),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=785374754),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=837699321),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1961554775),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1011598776),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1929299480),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1946920243),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1697319413),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=366943562),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=817213005),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=356767775),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=852933658),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=675209826),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=452705202),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1826393875),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1904247541),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1009411425),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1590888297),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=431675711),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=112764068),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1548801377),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=713730372),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=725305949),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=246777824),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1491412142),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1903360680),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=921343557),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=2145576731),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1264989382),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1364562697),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1252881975),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1766671642),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=706695439),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1557581987),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1075305378),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1134720252),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=240074152),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=791965815),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=998452876),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1509491699),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=644659277),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=69359283),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=937341234),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=896392597),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=2061796767),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1368648712),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1450043947),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=568860540),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1673775764),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1031107594),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1541022234),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=732944550),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=48900827),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1535876067),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1609281361),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1828613248),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1917438976),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1847819165),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1871462035),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1107083972),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=2117581798),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=182177920),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=431722704),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=291408984),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=889788803),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=645738289),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1959313712),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1778722605),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=2090834991),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1279716294),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1414671383),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=26492929),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=162734006),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=837437999),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=358791338),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=475611752),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1348136494),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=521683849),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=455753802),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=282770590),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=880075931),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1657900366),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1398090868),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=323143975),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=6910548),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=488608352),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1624866662),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=413572005),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1121024888),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1570289095),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=129436454),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=606867805),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1476878789),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=296373403),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=586540022),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=389615944),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1718949026),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1512165276),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=294142052),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=270359928),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=799040921),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1564122998),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=58909473),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1735124809),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=398525967),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1055325914),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=67496412),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1056938645),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=369340229),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=859466789),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1755193799),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=569017797),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=981932361),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=194836168),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=815544436),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1637051766),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1775122497),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1689774809),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=387493548),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1433469950),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=735274112),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1453893769),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=921160890),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=499657946),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1024118022),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1165315026),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1811639276),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=2085843627),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=950364018),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=691064295),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=759878406),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1220365283),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=2090835412),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1455049238),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=170704302),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=2030689523),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=2135917652),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=387549578),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1709944095),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=560256092),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1982242730),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1638111101),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=9470787),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=591298794),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1422071536),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=392415623),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=245934653),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=567089142),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1868382476),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=125681782),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=938197991),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=580765554),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1967459265),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1188856074),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1113042900),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=19763585),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1133417058),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1852497565),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=583048398),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1002815000),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1724813557),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=8324359),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=69034069),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1361307577),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1500818279),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=504211944),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=237499482),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1465272578),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1846629771),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1332629170),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=882903827),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1468562428),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1591677533),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=845954209),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=833369637),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=57001142),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=268131360),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=176772718),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=492903586),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1423080055),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1457216952),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=417894501),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=145093905),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1599510283),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=483678159),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1112650871),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1828870465),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1157686073),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=650519143),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=376461590),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=978979253),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1011117532),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=647769890),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=443465392),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1460082028),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=497816109),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=784337308),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1814126774),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1679776241),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=2011532094),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1547060439),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=358522965),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1709148571),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=2118319420),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=2105465348),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=308874902),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=853592908),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=197325022),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1585930893),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1492783190),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1157039360),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1155447043),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1913281028),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=685311588),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=241678703),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=287325552),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1133015496),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1394645364),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=2146553285),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1054860766),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1365477891),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=613790360),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1885310853),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=2017607570),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1468778367),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=419967296),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1443159227),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=994104587),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1629781071),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1400982749),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1080444558),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1779718399),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=331229855),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=2044365361),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=112719833),
#   DecisionTreeRegressor(max_features=0.5, min_samples_leaf=5,
#                         random_state=1417111239)],
#  'oob_prediction_': array([0.9645691 , 2.14358411, 2.24317991, ..., 0.33649964, 0.98794209,
#         0.57097569]),
#  'oob_score_': 0.9276132036933724,
#  '_sklearn_version': '1.3.0'}

# %%
import sys, os

# add read_io module to current path ()
# and import
file_path = 'D:\\GitHub\\DataIO\\'
sys.path.append(os.path.dirname(file_path))
import data_io as dio

# %%
sdate = '2024-05-10'
edate = '2024-05-15'

om_d, om_m = dio.load_omni(res='5m',sdate=sdate, edate=edate)

d_min = pd.to_datetime(sdate)
d_max = pd.to_datetime(edate)
om_d = om_d[(om_d['DateTime'] >= d_min-pd.DateOffset(minutes=5)) & (om_d['DateTime'] <= d_max+pd.DateOffset(minutes=5))]

# %%
# read fsim2 data and truncate to similar range as grace data
fi_d, fi_m = dio.load_fism2_daily(sdate=sdate, edate=edate)

# %%
fi_d = fi_d[['1300_02', '43000_09', '85550_13', '94400_18','DateTime']]
om_d = om_d[['SYM_H index', 'AE','DateTime']]

# %%
fi_d = fi_d.rename(columns={'DateTime':'DateTime_fism2'})
tol = pd.Timedelta('2.5 minute')
fi_d.index = fi_d['DateTime_fism2']
om_d.index = om_d['DateTime']

database = pd.merge_asof(left=om_d,right=fi_d,right_index=True,left_index=True,direction='nearest',tolerance=tol)
database = database.rename(columns={'DateTime':'DateTime_omni'})

# %%
database.head(2)
# Out:
#                      SYM_H index     AE       DateTime_omni       1300_02  \
# DateTime
# 2024-05-09 23:55:00          7.0    NaN 2024-05-09 23:55:00           NaN
# 2024-05-10 00:00:00          6.0  117.0 2024-05-10 00:00:00  1.185087e+08
#
#                          43000_09      85550_13      94400_18 DateTime_fism2
# DateTime
# 2024-05-09 23:55:00           NaN           NaN           NaN            NaT
# 2024-05-10 00:00:00  1.410783e+10  4.022602e+09  2.340119e+09     2024-05-10

# %%
cols = {'feature_cols': ['1300_02',
  '43000_09',
  '85550_13',
  '94400_18',
  'SYM_H index',
  'AE'],
 'target_cols': '400kmDensity',
 'time_cols': ['DateTime', 'storm', 'storm phase'],
 'log_col': ['1300_02', '43000_09', '85550_13', '94400_18'],
 'lt_col': ['SatMagLT']}

# %%
reg_x, _ = dat_create(dat=database,col=cols['feature_cols'],
                      log_col=cols['log_col'],
                      lt_col=cols['lt_col'],
                      y_col='DateTime_omni',t_col=['DateTime_omni'])
# Out:
# Could not add SatMagLT as a cos/sin time column

# %%
reg_x.to_hdf("D:\data\SatDensities\FI_GEO_RFdat_AIMFAHR_inputs_MayStorm.hdf",format='table',key='inputs',complevel=3)
